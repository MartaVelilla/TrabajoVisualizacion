# %% [markdown]
# # Final proyect

# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
import pandas as pd

df = pd.read_csv("HealthDataSet.csv", sep=",", encoding="utf-8-sig", index_col=False)

print(df.head())
# Out:
#                   Date  Alteraciones de la respiración (count)  \
# 0  2024-04-18 00:00:00                                     NaN
# 1  2024-04-19 00:00:00                                     NaN
# 2  2024-04-20 00:00:00                                     NaN
# 3  2024-04-21 00:00:00                                     NaN
# 4  2024-04-22 00:00:00                                     NaN
#
#    Análisis del Sueño [Total] (hr)  Análisis del Sueño [Asleep] (hr)  \
# 0                         7.316667                               0.0
# 1                         7.233333                               0.0
# 2                         9.250000                               0.0
# 3                         7.200000                               0.0
# 4                         7.750000                               0.0
#
#    Análisis del Sueño [In Bed] (hr)  Análisis del Sueño [Core] (hr)  \
# 0                          7.316667                        4.833333
# 1                          7.233333                        4.675000
# 2                          9.250000                        6.825000
# 3                          7.200000                        4.875000
# 4                          7.750000                        5.166667
#
#    Análisis del Sueño [Deep] (hr)  Análisis del Sueño [REM] (hr)  \
# 0                        0.833333                       1.650000
# 1                        0.541667                       2.016667
# 2                        0.691667                       1.733333
# 3                        0.691667                       1.633333
# 4                        0.816667                       1.766667
#
#    Análisis del Sueño [Awake] (hr)  Frecuencia Cardíaca [Min] (count/min)  \
# 0                         0.108333                                   43.0
# 1                         0.116667                                   47.0
# 2                         0.200000                                   42.0
# 3                         0.250000                                   46.0
# 4                         0.258333                                   45.0
#
#    ...  Frecuencia Cardíaca [Avg] (count/min)  \
# 0  ...                                   43.0
# 1  ...                                   47.0
# 2  ...                                   42.0
# 3  ...                                   46.0
# 4  ...                                   45.0
#
#    Frecuencia respiratoria (count/min)  Hora de Estar de Pie de Apple (count)  \
# 0                                14.83                                   15.0
# 1                                13.84                                   14.0
# 2                                14.28                                   13.0
# 3                                14.57                                   14.0
# 4                                14.50                                   14.0
#
#    Minutos Conscientes (min)  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#    Promedio de Frecuencia Cardíaca al Caminar (count/min)  \
# 0                                               90.0
# 1                                               93.0
# 2                                                NaN
# 3                                               89.0
# 4                                               93.0
#
#    Temperatura de Muñeca Mientras Duerme de Apple (degC)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Tiempo de Ejercicio de Apple (min)  Tiempo de Movimiento de Apple (min)  \
# 0                                22.0                                  NaN
# 1                                64.0                                  NaN
# 2                                11.0                                  NaN
# 3                                66.0                                  NaN
# 4                                47.0                                  NaN
#
#    Tiempo en Luz de Día (min)  Variabilidad de Frecuencia Cardíaca (ms)
# 0                        43.0                                      83.06
# 1                         NaN                                      66.71
# 2                         6.0                                      95.21
# 3                        66.0                                     101.29
# 4                        45.0                                     105.86
#
# [5 rows x 21 columns]

# %%
df.tail(5)
# Out:
#                     Date  Alteraciones de la respiración (count)  \
# 524  2025-09-24 00:00:00                                     NaN
# 525  2025-09-25 00:00:00                                     NaN
# 526  2025-09-26 00:00:00                                     NaN
# 527  2025-09-27 00:00:00                                     NaN
# 528  2025-09-28 00:00:00                                     NaN
#
#      Análisis del Sueño [Total] (hr)  Análisis del Sueño [Asleep] (hr)  \
# 524                         6.475000                          1.116667
# 525                         8.466667                          0.000000
# 526                         9.191667                          0.000000
# 527                         8.791667                          0.000000
# 528                         9.241667                          0.000000
#
#      Análisis del Sueño [In Bed] (hr)  Análisis del Sueño [Core] (hr)  \
# 524                               0.0                        3.391667
# 525                               0.0                        5.391667
# 526                               0.0                        5.741667
# 527                               0.0                        6.200000
# 528                               0.0                        6.558333
#
#      Análisis del Sueño [Deep] (hr)  Análisis del Sueño [REM] (hr)  \
# 524                        0.875000                       1.091667
# 525                        0.783333                       2.291667
# 526                        1.083333                       2.366667
# 527                        1.125000                       1.466667
# 528                        0.550000                       2.133333
#
#      Análisis del Sueño [Awake] (hr)  Frecuencia Cardíaca [Min] (count/min)  \
# 524                         0.275000                                   47.0
# 525                         0.158333                                   46.0
# 526                         0.141667                                   45.0
# 527                         0.425000                                   47.0
# 528                         0.200000                                   47.0
#
#      ...  Frecuencia Cardíaca [Avg] (count/min)  \
# 524  ...                                   47.0
# 525  ...                                   46.0
# 526  ...                                   45.0
# 527  ...                                   47.0
# 528  ...                                   47.0
#
#      Frecuencia respiratoria (count/min)  \
# 524                                14.74
# 525                                15.88
# 526                                14.17
# 527                                14.32
# 528                                14.28
#
#      Hora de Estar de Pie de Apple (count)  Minutos Conscientes (min)  \
# 524                                   14.0                        NaN
# 525                                   14.0                        NaN
# 526                                   14.0                        NaN
# 527                                   13.0                        NaN
# 528                                    6.0                        NaN
#
#      Promedio de Frecuencia Cardíaca al Caminar (count/min)  \
# 524                                               94.5
# 525                                               99.0
# 526                                              118.0
# 527                                              130.0
# 528                                               70.0
#
#      Temperatura de Muñeca Mientras Duerme de Apple (degC)  \
# 524                                                NaN
# 525                                                NaN
# 526                                                NaN
# 527                                                NaN
# 528                                                NaN
#
#      Tiempo de Ejercicio de Apple (min)  Tiempo de Movimiento de Apple (min)  \
# 524                                15.0                                  NaN
# 525                                32.0                                  NaN
# 526                                45.0                                  NaN
# 527                                80.0                                  NaN
# 528                                 7.0                                  NaN
#
#      Tiempo en Luz de Día (min)  Variabilidad de Frecuencia Cardíaca (ms)
# 524                        22.0                                      56.19
# 525                       101.0                                      68.34
# 526                       212.0                                      66.95
# 527                       241.0                                      54.14
# 528                        10.0                                      89.49
#
# [5 rows x 21 columns]

# %%
# Eliminar columnas que solo tienen NaN
df = df.dropna(how='all', axis=1)
df
# Out:
#                     Date  Análisis del Sueño [Total] (hr)  \
# 0    2024-04-18 00:00:00                         7.316667
# 1    2024-04-19 00:00:00                         7.233333
# 2    2024-04-20 00:00:00                         9.250000
# 3    2024-04-21 00:00:00                         7.200000
# 4    2024-04-22 00:00:00                         7.750000
# ..                   ...                              ...
# 524  2025-09-24 00:00:00                         6.475000
# 525  2025-09-25 00:00:00                         8.466667
# 526  2025-09-26 00:00:00                         9.191667
# 527  2025-09-27 00:00:00                         8.791667
# 528  2025-09-28 00:00:00                         9.241667
#
#      Análisis del Sueño [Asleep] (hr)  Análisis del Sueño [In Bed] (hr)  \
# 0                            0.000000                          7.316667
# 1                            0.000000                          7.233333
# 2                            0.000000                          9.250000
# 3                            0.000000                          7.200000
# 4                            0.000000                          7.750000
# ..                                ...                               ...
# 524                          1.116667                          0.000000
# 525                          0.000000                          0.000000
# 526                          0.000000                          0.000000
# 527                          0.000000                          0.000000
# 528                          0.000000                          0.000000
#
#      Análisis del Sueño [Core] (hr)  Análisis del Sueño [Deep] (hr)  \
# 0                          4.833333                        0.833333
# 1                          4.675000                        0.541667
# 2                          6.825000                        0.691667
# 3                          4.875000                        0.691667
# 4                          5.166667                        0.816667
# ..                              ...                             ...
# 524                        3.391667                        0.875000
# 525                        5.391667                        0.783333
# 526                        5.741667                        1.083333
# 527                        6.200000                        1.125000
# 528                        6.558333                        0.550000
#
#      Análisis del Sueño [REM] (hr)  Análisis del Sueño [Awake] (hr)  \
# 0                         1.650000                         0.108333
# 1                         2.016667                         0.116667
# 2                         1.733333                         0.200000
# 3                         1.633333                         0.250000
# 4                         1.766667                         0.258333
# ..                             ...                              ...
# 524                       1.091667                         0.275000
# 525                       2.291667                         0.158333
# 526                       2.366667                         0.141667
# 527                       1.466667                         0.425000
# 528                       2.133333                         0.200000
#
#      Frecuencia Cardíaca [Min] (count/min)  \
# 0                                     43.0
# 1                                     47.0
# 2                                     42.0
# 3                                     46.0
# 4                                     45.0
# ..                                     ...
# 524                                   47.0
# 525                                   46.0
# 526                                   45.0
# 527                                   47.0
# 528                                   47.0
#
#      Frecuencia Cardíaca [Max] (count/min)  \
# 0                                    152.0
# 1                                    158.0
# 2                                    113.0
# 3                                    147.0
# 4                                    143.0
# ..                                     ...
# 524                                  126.0
# 525                                  146.0
# 526                                  138.0
# 527                                  191.0
# 528                                  107.0
#
#      Frecuencia Cardíaca [Avg] (count/min)  \
# 0                                     43.0
# 1                                     47.0
# 2                                     42.0
# 3                                     46.0
# 4                                     45.0
# ..                                     ...
# 524                                   47.0
# 525                                   46.0
# 526                                   45.0
# 527                                   47.0
# 528                                   47.0
#
#      Frecuencia respiratoria (count/min)  \
# 0                                  14.83
# 1                                  13.84
# 2                                  14.28
# 3                                  14.57
# 4                                  14.50
# ..                                   ...
# 524                                14.74
# 525                                15.88
# 526                                14.17
# 527                                14.32
# 528                                14.28
#
#      Hora de Estar de Pie de Apple (count)  Minutos Conscientes (min)  \
# 0                                     15.0                        NaN
# 1                                     14.0                        NaN
# 2                                     13.0                        NaN
# 3                                     14.0                        NaN
# 4                                     14.0                        NaN
# ..                                     ...                        ...
# 524                                   14.0                        NaN
# 525                                   14.0                        NaN
# 526                                   14.0                        NaN
# 527                                   13.0                        NaN
# 528                                    6.0                        NaN
#
#      Promedio de Frecuencia Cardíaca al Caminar (count/min)  \
# 0                                                 90.0
# 1                                                 93.0
# 2                                                  NaN
# 3                                                 89.0
# 4                                                 93.0
# ..                                                 ...
# 524                                               94.5
# 525                                               99.0
# 526                                              118.0
# 527                                              130.0
# 528                                               70.0
#
#      Tiempo de Ejercicio de Apple (min)  Tiempo en Luz de Día (min)  \
# 0                                  22.0                        43.0
# 1                                  64.0                         NaN
# 2                                  11.0                         6.0
# 3                                  66.0                        66.0
# 4                                  47.0                        45.0
# ..                                  ...                         ...
# 524                                15.0                        22.0
# 525                                32.0                       101.0
# 526                                45.0                       212.0
# 527                                80.0                       241.0
# 528                                 7.0                        10.0
#
#      Variabilidad de Frecuencia Cardíaca (ms)
# 0                                        83.06
# 1                                        66.71
# 2                                        95.21
# 3                                       101.29
# 4                                       105.86
# ..                                         ...
# 524                                      56.19
# 525                                      68.34
# 526                                      66.95
# 527                                      54.14
# 528                                      89.49
#
# [529 rows x 18 columns]
